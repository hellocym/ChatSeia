# %%
dataset = []
with open('data/all.txt', 'r', encoding='utf-8') as file:
  dataset = file.readlines()
  print(f'Loaded {len(dataset)} entries')
# Out:
# Loaded 38402 entries

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

token = os.getenv("TOKEN")

def get_embedding(text):
    url = "https://api.siliconflow.cn/v1/embeddings"

    payload = {
        "model": "BAAI/bge-m3",
        "input": "Silicon flow embedding online: fast, affordable, and high-quality embedding services. come try it out!",
        "encoding_format": "float"
    }
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json"
    }

    response = requests.request("POST", url, json=payload, headers=headers)

    return response.json()['data'][0]['embedding']

# %%
try:
    text = "Embed this string for me!"
    vector = get_embedding(text)
    print(f"向量维度: {len(vector)}")
    print(f"向量前5个值: {vector[:5]}")
except Exception as e:
    print(f"错误: {e}")
# Out:
# 向量维度: 1024
# 向量前5个值: [-0.046083894, 0.03211734, -0.035460908, -0.013230968, -0.0021028642]

# %%
import ollama

EMBEDDING_MODEL = r'E:\lmstudio\mradermacher\Conan-embedding-v1-GGUF'
LANGUAGE_MODEL = r'E:\lmstudio\unsloth\Qwen3-30B-A3B-GGUF'

# Each element in the VECTOR_DB will be a tuple (chunk, embedding)
# The embedding is a list of floats, for example: [0.1, 0.04, -0.34, 0.21, ...]
VECTOR_DB = []

def add_chunk_to_database(chunk):
  embedding = get_embedding(chunk)
  VECTOR_DB.append((chunk, embedding))

# %%
for i, chunk in enumerate(dataset):
  add_chunk_to_database(chunk)
  print(f'Added chunk {i+1}/{len(dataset)} to the database\r')
# Out:
# Added chunk 1/38402 to the database
# Added chunk 2/38402 to the database
# Added chunk 3/38402 to the database
# Added chunk 4/38402 to the database
# Added chunk 5/38402 to the database
# Added chunk 6/38402 to the database
# Added chunk 7/38402 to the database
# Added chunk 8/38402 to the database
# Added chunk 9/38402 to the database
# Added chunk 10/38402 to the database
# Added chunk 11/38402 to the database
# Added chunk 12/38402 to the database
# Added chunk 13/38402 to the database
# Added chunk 14/38402 to the database
# Added chunk 15/38402 to the database
# Added chunk 16/38402 to the database
# Added chunk 17/38402 to the database
# Added chunk 18/38402 to the database
# Added chunk 19/38402 to the database
# Added chunk 20/38402 to the database
# Added chunk 21/38402 to the database
# Added chunk 22/38402 to the database
# Added chunk 23/38402 to the database
# Added chunk 24/38402 to the database
# Added chunk 25/38402 to the database
# Added chunk 26/38402 to the database
# Added chunk 27/38402 to the database
# Added chunk 28/38402 to the database
# Added chunk 29/38402 to the database
# Added chunk 30/38402 to the database
# Added chunk 31/38402 to the database
# Added chunk 32/38402 to the database
# Added chunk 33/38402 to the database
# Added chunk 34/38402 to the database
# Added chunk 35/38402 to the database
# Added chunk 36/38402 to the database
# Added chunk 37/38402 to the database
# Added chunk 38/38402 to the database
# Added chunk 39/38402 to the database
# Added chunk 40/38402 to the database
# Added chunk 41/38402 to the database
# Added chunk 42/38402 to the database
# Added chunk 43/38402 to the database
# Added chunk 44/38402 to the database
# Added chunk 45/38402 to the database
# Added chunk 46/38402 to the database
# Added chunk 47/38402 to the database
# Added chunk 48/38402 to the database
# Added chunk 49/38402 to the database
# Added chunk 50/38402 to the database
# Added chunk 51/38402 to the database
# Added chunk 52/38402 to the database
# Added chunk 53/38402 to the database
# Added chunk 54/38402 to the database
# Added chunk 55/38402 to the database
# Added chunk 56/38402 to the database
# Added chunk 57/38402 to the database
# Added chunk 58/38402 to the database
# Added chunk 59/38402 to the database
# Added chunk 60/38402 to the database
# Added chunk 61/38402 to the database
# Added chunk 62/38402 to the database
# Added chunk 63/38402 to the database
# Added chunk 64/38402 to the database
# Added chunk 65/38402 to the database
# Added chunk 66/38402 to the database
# Added chunk 67/38402 to the database
# Added chunk 68/38402 to the database
# Added chunk 69/38402 to the database
# Added chunk 70/38402 to the database
# Added chunk 71/38402 to the database
# Added chunk 72/38402 to the database
# Added chunk 73/38402 to the database
# Added chunk 74/38402 to the database
# Added chunk 75/38402 to the database
# Added chunk 76/38402 to the database
# Added chunk 77/38402 to the database
# Added chunk 78/38402 to the database
# Added chunk 79/38402 to the database
# Added chunk 80/38402 to the database
# Added chunk 81/38402 to the database
# Added chunk 82/38402 to the database
# Added chunk 83/38402 to the database
# Added chunk 84/38402 to the database
# Added chunk 85/38402 to the database
# Added chunk 86/38402 to the database
# Added chunk 87/38402 to the database
# Added chunk 88/38402 to the database
# Added chunk 89/38402 to the database
# Added chunk 90/38402 to the database
# Added chunk 91/38402 to the database
# Added chunk 92/38402 to the database
# Added chunk 93/38402 to the database
# Added chunk 94/38402 to the database
# Added chunk 95/38402 to the database
# Added chunk 96/38402 to the database
# Added chunk 97/38402 to the database
# Added chunk 98/38402 to the database
# Added chunk 99/38402 to the database
# Added chunk 100/38402 to the database
# Added chunk 101/38402 to the database
# Added chunk 102/38402 to the database
# Added chunk 103/38402 to the database
# Added chunk 104/38402 to the database
# Added chunk 105/38402 to the database
# Added chunk 106/38402 to the database
# Added chunk 107/38402 to the database
# Added chunk 108/38402 to the database
# Added chunk 109/38402 to the database
# Added chunk 110/38402 to the database
# Added chunk 111/38402 to the database
# Added chunk 112/38402 to the database
# Added chunk 113/38402 to the database
# Added chunk 114/38402 to the database
# Added chunk 115/38402 to the database
# Added chunk 116/38402 to the database
# Added chunk 117/38402 to the database
# Added chunk 118/38402 to the database
# Added chunk 119/38402 to the database
# Added chunk 120/38402 to the database
# Added chunk 121/38402 to the database
# Added chunk 122/38402 to the database
# Added chunk 123/38402 to the database
# Added chunk 124/38402 to the database
# Added chunk 125/38402 to the database
# Added chunk 126/38402 to the database
# Added chunk 127/38402 to the database
# Added chunk 128/38402 to the database
# Added chunk 129/38402 to the database
# Added chunk 130/38402 to the database
# Added chunk 131/38402 to the database
# Added chunk 132/38402 to the database
# Added chunk 133/38402 to the database
# Added chunk 134/38402 to the database
# Added chunk 135/38402 to the database
# Added chunk 136/38402 to the database
# Added chunk 137/38402 to the database
# Added chunk 138/38402 to the database
# Added chunk 139/38402 to the database
# Added chunk 140/38402 to the database
# Added chunk 141/38402 to the database
# Added chunk 142/38402 to the database
# Added chunk 143/38402 to the database
# Added chunk 144/38402 to the database
# Added chunk 145/38402 to the database
# Added chunk 146/38402 to the database
# Added chunk 147/38402 to the database
# Added chunk 148/38402 to the database
# Added chunk 149/38402 to the database
# Added chunk 150/38402 to the database
# Added chunk 151/38402 to the database
# Added chunk 152/38402 to the database
# Added chunk 153/38402 to the database
# Added chunk 154/38402 to the database
# Added chunk 155/38402 to the database
# Added chunk 156/38402 to the database
# Added chunk 157/38402 to the database
# Added chunk 158/38402 to the database
# Added chunk 159/38402 to the database
# Added chunk 160/38402 to the database
# Added chunk 161/38402 to the database
# Added chunk 162/38402 to the database
# Added chunk 163/38402 to the database
# Added chunk 164/38402 to the database
# Added chunk 165/38402 to the database
# Added chunk 166/38402 to the database
# Added chunk 167/38402 to the database
# Added chunk 168/38402 to the database
# Added chunk 169/38402 to the database
# Added chunk 170/38402 to the database
# Added chunk 171/38402 to the database
# Added chunk 172/38402 to the database
# Added chunk 173/38402 to the database
# Added chunk 174/38402 to the database
# Added chunk 175/38402 to the database
# Added chunk 176/38402 to the database
# Added chunk 177/38402 to the database
# Added chunk 178/38402 to the database
# Added chunk 179/38402 to the database
# Added chunk 180/38402 to the database
# Added chunk 181/38402 to the database
# Added chunk 182/38402 to the database
# Added chunk 183/38402 to the database
# Added chunk 184/38402 to the database
# Added chunk 185/38402 to the database
# Added chunk 186/38402 to the database
# Added chunk 187/38402 to the database
# Added chunk 188/38402 to the database
# Added chunk 189/38402 to the database
# Added chunk 190/38402 to the database
# Added chunk 191/38402 to the database
# Added chunk 192/38402 to the database
# Added chunk 193/38402 to the database
# Added chunk 194/38402 to the database
# Added chunk 195/38402 to the database
# Added chunk 196/38402 to the database
# Added chunk 197/38402 to the database
# Added chunk 198/38402 to the database
# Added chunk 199/38402 to the database
# Added chunk 200/38402 to the database
# Added chunk 201/38402 to the database
# Added chunk 202/38402 to the database
# Added chunk 203/38402 to the database
# Added chunk 204/38402 to the database
# Added chunk 205/38402 to the database
# Added chunk 206/38402 to the database
# Added chunk 207/38402 to the database
# Added chunk 208/38402 to the database
# Added chunk 209/38402 to the database
# Added chunk 210/38402 to the database
# Added chunk 211/38402 to the database
# Added chunk 212/38402 to the database
# Added chunk 213/38402 to the database
# Added chunk 214/38402 to the database
# Added chunk 215/38402 to the database
# Added chunk 216/38402 to the database
# Added chunk 217/38402 to the database
# Added chunk 218/38402 to the database
# Added chunk 219/38402 to the database
# Added chunk 220/38402 to the database
# Added chunk 221/38402 to the database
# Added chunk 222/38402 to the database
# Added chunk 223/38402 to the database
# Added chunk 224/38402 to the database
# Added chunk 225/38402 to the database
# Added chunk 226/38402 to the database
# Added chunk 227/38402 to the database
# Added chunk 228/38402 to the database
# Added chunk 229/38402 to the database
# Added chunk 230/38402 to the database
# Added chunk 231/38402 to the database
# Added chunk 232/38402 to the database
# Added chunk 233/38402 to the database
# Added chunk 234/38402 to the database
# Added chunk 235/38402 to the database
# Added chunk 236/38402 to the database
# Added chunk 237/38402 to the database
# Added chunk 238/38402 to the database
# Added chunk 239/38402 to the database
# Added chunk 240/38402 to the database
# Added chunk 241/38402 to the database
# Added chunk 242/38402 to the database
# Added chunk 243/38402 to the database
# Added chunk 244/38402 to the database
# Added chunk 245/38402 to the database
# Added chunk 246/38402 to the database
# Added chunk 247/38402 to the database
# Added chunk 248/38402 to the database
# Added chunk 249/38402 to the database
# Added chunk 250/38402 to the database
# Added chunk 251/38402 to the database
# Added chunk 252/38402 to the database
# Added chunk 253/38402 to the database
# Added chunk 254/38402 to the database
# Added chunk 255/38402 to the database
# Added chunk 256/38402 to the database
# Added chunk 257/38402 to the database
# Added chunk 258/38402 to the database
# Added chunk 259/38402 to the database
# Added chunk 260/38402 to the database
# Added chunk 261/38402 to the database
# Added chunk 262/38402 to the database
# Added chunk 263/38402 to the database
# Added chunk 264/38402 to the database
# Added chunk 265/38402 to the database
# Added chunk 266/38402 to the database
# Added chunk 267/38402 to the database
# Added chunk 268/38402 to the database
# Added chunk 269/38402 to the database
# Added chunk 270/38402 to the database
# Added chunk 271/38402 to the database
# Added chunk 272/38402 to the database
# Added chunk 273/38402 to the database
# Added chunk 274/38402 to the database
# Added chunk 275/38402 to the database
# Added chunk 276/38402 to the database
# Added chunk 277/38402 to the database
# Added chunk 278/38402 to the database
# Added chunk 279/38402 to the database
# Added chunk 280/38402 to the database
# Added chunk 281/38402 to the database
# Added chunk 282/38402 to the database
# Added chunk 283/38402 to the database
# Added chunk 284/38402 to the database
# Added chunk 285/38402 to the database
# Added chunk 286/38402 to the database
# Added chunk 287/38402 to the database
# Added chunk 288/38402 to the database
# Added chunk 289/38402 to the database
# Added chunk 290/38402 to the database
# Added chunk 291/38402 to the database
# Added chunk 292/38402 to the database
# Added chunk 293/38402 to the database
# Added chunk 294/38402 to the database
# Added chunk 295/38402 to the database
# Added chunk 296/38402 to the database
# Added chunk 297/38402 to the database
# Added chunk 298/38402 to the database
# Added chunk 299/38402 to the database
# Added chunk 300/38402 to the database
# Added chunk 301/38402 to the database
# Added chunk 302/38402 to the database
# Added chunk 303/38402 to the database
# Added chunk 304/38402 to the database
# Added chunk 305/38402 to the database
# Added chunk 306/38402 to the database
# Added chunk 307/38402 to the database
# Added chunk 308/38402 to the database
# Added chunk 309/38402 to the database
# Added chunk 310/38402 to the database
# Added chunk 311/38402 to the database
# Added chunk 312/38402 to the database
# Added chunk 313/38402 to the database
# Added chunk 314/38402 to the database
# Added chunk 315/38402 to the database
# Added chunk 316/38402 to the database
# Added chunk 317/38402 to the database
# Added chunk 318/38402 to the database
# Added chunk 319/38402 to the database
# Added chunk 320/38402 to the database
# Added chunk 321/38402 to the database
# Added chunk 322/38402 to the database
# Added chunk 323/38402 to the database
# Added chunk 324/38402 to the database
# Added chunk 325/38402 to the database
# Added chunk 326/38402 to the database
# Added chunk 327/38402 to the database
# Added chunk 328/38402 to the database
# Added chunk 329/38402 to the database
# Added chunk 330/38402 to the database
# Added chunk 331/38402 to the database
# Added chunk 332/38402 to the database
# Added chunk 333/38402 to the database
# Added chunk 334/38402 to the database
# Added chunk 335/38402 to the database
# Added chunk 336/38402 to the database
# Added chunk 337/38402 to the database
# Added chunk 338/38402 to the database
# Added chunk 339/38402 to the database
# Added chunk 340/38402 to the database
# Added chunk 341/38402 to the database
# Added chunk 342/38402 to the database
# Added chunk 343/38402 to the database
# Added chunk 344/38402 to the database
# Added chunk 345/38402 to the database
# Added chunk 346/38402 to the database
# Added chunk 347/38402 to the database
# Added chunk 348/38402 to the database
# Added chunk 349/38402 to the database
# Added chunk 350/38402 to the database
# Added chunk 351/38402 to the database
# Added chunk 352/38402 to the database
# Added chunk 353/38402 to the database
# Added chunk 354/38402 to the database
# Added chunk 355/38402 to the database
# Added chunk 356/38402 to the database
# Added chunk 357/38402 to the database
# Added chunk 358/38402 to the database
# Added chunk 359/38402 to the database
# Added chunk 360/38402 to the database
# Added chunk 361/38402 to the database
# Added chunk 362/38402 to the database
# Added chunk 363/38402 to the database
# Added chunk 364/38402 to the database
# Added chunk 365/38402 to the database
# Added chunk 366/38402 to the database
# Added chunk 367/38402 to the database
# Added chunk 368/38402 to the database
# Added chunk 369/38402 to the database
# Added chunk 370/38402 to the database
# Added chunk 371/38402 to the database
# Added chunk 372/38402 to the database
# Added chunk 373/38402 to the database
# Added chunk 374/38402 to the database
# Added chunk 375/38402 to the database
# Added chunk 376/38402 to the database
# Added chunk 377/38402 to the database
# Added chunk 378/38402 to the database
# Added chunk 379/38402 to the database
# Added chunk 380/38402 to the database
# Added chunk 381/38402 to the database
# Added chunk 382/38402 to the database
# Added chunk 383/38402 to the database
# Added chunk 384/38402 to the database
# Added chunk 385/38402 to the database
# Added chunk 386/38402 to the database
# Added chunk 387/38402 to the database
# Added chunk 388/38402 to the database
# Added chunk 389/38402 to the database
# Added chunk 390/38402 to the database
# Added chunk 391/38402 to the database
# Added chunk 392/38402 to the database
# Added chunk 393/38402 to the database
# Added chunk 394/38402 to the database
# Added chunk 395/38402 to the database
# Added chunk 396/38402 to the database
# Added chunk 397/38402 to the database
# Added chunk 398/38402 to the database
# Added chunk 399/38402 to the database
# Added chunk 400/38402 to the database
# Added chunk 401/38402 to the database
# Added chunk 402/38402 to the database
# Added chunk 403/38402 to the database
# Added chunk 404/38402 to the database
# Added chunk 405/38402 to the database
# Added chunk 406/38402 to the database
# Added chunk 407/38402 to the database
# Added chunk 408/38402 to the database
# Added chunk 409/38402 to the database
# Added chunk 410/38402 to the database
# Added chunk 411/38402 to the database
# Added chunk 412/38402 to the database
# Added chunk 413/38402 to the database
# Added chunk 414/38402 to the database
# Added chunk 415/38402 to the database
# Added chunk 416/38402 to the database
# Added chunk 417/38402 to the database
# Added chunk 418/38402 to the database
# Added chunk 419/38402 to the database
# Added chunk 420/38402 to the database
# Added chunk 421/38402 to the database
# Added chunk 422/38402 to the database
# Added chunk 423/38402 to the database
# Added chunk 424/38402 to the database
# Added chunk 425/38402 to the database
# Added chunk 426/38402 to the database
# Added chunk 427/38402 to the database
# Added chunk 428/38402 to the database
# Added chunk 429/38402 to the database
# Added chunk 430/38402 to the database
# Added chunk 431/38402 to the database
# Added chunk 432/38402 to the database
# Added chunk 433/38402 to the database
# Added chunk 434/38402 to the database
# Added chunk 435/38402 to the database
# Added chunk 436/38402 to the database
# Added chunk 437/38402 to the database
# Added chunk 438/38402 to the database
# Added chunk 439/38402 to the database
# Added chunk 440/38402 to the database
# Added chunk 441/38402 to the database
# Added chunk 442/38402 to the database
# Added chunk 443/38402 to the database
# Added chunk 444/38402 to the database
# Added chunk 445/38402 to the database
# Added chunk 446/38402 to the database
# Added chunk 447/38402 to the database
# Added chunk 448/38402 to the database
# Added chunk 449/38402 to the database
# Added chunk 450/38402 to the database
# Added chunk 451/38402 to the database
# Added chunk 452/38402 to the database
# Added chunk 453/38402 to the database
# Added chunk 454/38402 to the database
# Added chunk 455/38402 to the database
# Added chunk 456/38402 to the database
# Added chunk 457/38402 to the database
# Added chunk 458/38402 to the database
# Added chunk 459/38402 to the database
# Added chunk 460/38402 to the database
# Added chunk 461/38402 to the database
# Added chunk 462/38402 to the database
# Added chunk 463/38402 to the database
# Added chunk 464/38402 to the database
# Added chunk 465/38402 to the database
# Added chunk 466/38402 to the database
# Added chunk 467/38402 to the database
# Added chunk 468/38402 to the database
# Added chunk 469/38402 to the database
# Added chunk 470/38402 to the database
# Added chunk 471/38402 to the database
# Added chunk 472/38402 to the database
# Added chunk 473/38402 to the database
# Added chunk 474/38402 to the database
# Added chunk 475/38402 to the database
# Added chunk 476/38402 to the database
# Added chunk 477/38402 to the database
# Added chunk 478/38402 to the database
# Added chunk 479/38402 to the database
# Added chunk 480/38402 to the database
# Added chunk 481/38402 to the database
# Added chunk 482/38402 to the database
# Added chunk 483/38402 to the database
# Added chunk 484/38402 to the database
# Added chunk 485/38402 to the database
# Added chunk 486/38402 to the database
# Added chunk 487/38402 to the database
# Added chunk 488/38402 to the database
# Added chunk 489/38402 to the database
# Added chunk 490/38402 to the database
# Added chunk 491/38402 to the database
# Added chunk 492/38402 to the database
# Added chunk 493/38402 to the database
# Added chunk 494/38402 to the database
# Added chunk 495/38402 to the database
# Added chunk 496/38402 to the database
# Added chunk 497/38402 to the database
# Added chunk 498/38402 to the database
# Added chunk 499/38402 to the database
# Added chunk 500/38402 to the database
# Added chunk 501/38402 to the database
# Added chunk 502/38402 to the database
# Added chunk 503/38402 to the database
# Added chunk 504/38402 to the database
# Added chunk 505/38402 to the database
# Added chunk 506/38402 to the database
# Added chunk 507/38402 to the database
# Added chunk 508/38402 to the database
# Added chunk 509/38402 to the database
# Added chunk 510/38402 to the database
# Added chunk 511/38402 to the database
# Added chunk 512/38402 to the database
# Added chunk 513/38402 to the database
# Added chunk 514/38402 to the database
# Added chunk 515/38402 to the database
# Added chunk 516/38402 to the database
# Added chunk 517/38402 to the database
# Added chunk 518/38402 to the database
# Added chunk 519/38402 to the database
# Added chunk 520/38402 to the database
# Added chunk 521/38402 to the database
# Added chunk 522/38402 to the database
# Added chunk 523/38402 to the database
# Added chunk 524/38402 to the database
# Added chunk 525/38402 to the database
# Added chunk 526/38402 to the database
# Added chunk 527/38402 to the database
# Added chunk 528/38402 to the database
# Added chunk 529/38402 to the database
# Added chunk 530/38402 to the database
# Added chunk 531/38402 to the database
# Added chunk 532/38402 to the database
# Added chunk 533/38402 to the database
# Added chunk 534/38402 to the database
# Added chunk 535/38402 to the database
# Added chunk 536/38402 to the database
# Added chunk 537/38402 to the database
# Added chunk 538/38402 to the database
# Added chunk 539/38402 to the database
# Added chunk 540/38402 to the database
# Added chunk 541/38402 to the database
# Added chunk 542/38402 to the database
# Added chunk 543/38402 to the database
# Added chunk 544/38402 to the database
# Added chunk 545/38402 to the database
# Added chunk 546/38402 to the database
# Added chunk 547/38402 to the database
# Added chunk 548/38402 to the database
# Added chunk 549/38402 to the database
# Added chunk 550/38402 to the database
# Added chunk 551/38402 to the database
# Added chunk 552/38402 to the database
# Added chunk 553/38402 to the database
# Added chunk 554/38402 to the database
# Added chunk 555/38402 to the database
# Added chunk 556/38402 to the database
# Added chunk 557/38402 to the database
# Added chunk 558/38402 to the database
# Added chunk 559/38402 to the database
# Added chunk 560/38402 to the database
# Added chunk 561/38402 to the database
# Added chunk 562/38402 to the database
# Added chunk 563/38402 to the database
# Added chunk 564/38402 to the database
# Added chunk 565/38402 to the database
# Added chunk 566/38402 to the database
# Added chunk 567/38402 to the database
# Added chunk 568/38402 to the database
# Added chunk 569/38402 to the database
# Added chunk 570/38402 to the database
# Added chunk 571/38402 to the database
# Added chunk 572/38402 to the database
# Added chunk 573/38402 to the database
# Added chunk 574/38402 to the database
# Added chunk 575/38402 to the database
# Added chunk 576/38402 to the database
# Added chunk 577/38402 to the database
# Added chunk 578/38402 to the database
# Added chunk 579/38402 to the database
# Added chunk 580/38402 to the database
# Added chunk 581/38402 to the database
# Added chunk 582/38402 to the database
# Added chunk 583/38402 to the database
# Added chunk 584/38402 to the database
# Added chunk 585/38402 to the database
# Added chunk 586/38402 to the database
# Added chunk 587/38402 to the database
# Added chunk 588/38402 to the database
# Added chunk 589/38402 to the database
# Added chunk 590/38402 to the database
# Added chunk 591/38402 to the database
# Added chunk 592/38402 to the database
# Added chunk 593/38402 to the database
# Added chunk 594/38402 to the database
# Added chunk 595/38402 to the database
# Added chunk 596/38402 to the database
# Added chunk 597/38402 to the database
# Added chunk 598/38402 to the database
# Added chunk 599/38402 to the database
# Added chunk 600/38402 to the database
# Added chunk 601/38402 to the database
# Added chunk 602/38402 to the database
# Added chunk 603/38402 to the database
# Added chunk 604/38402 to the database
# Added chunk 605/38402 to the database
# Added chunk 606/38402 to the database
# Added chunk 607/38402 to the database
# Added chunk 608/38402 to the database
# Added chunk 609/38402 to the database
# Added chunk 610/38402 to the database
# Added chunk 611/38402 to the database
# Added chunk 612/38402 to the database
# Added chunk 613/38402 to the database
# Added chunk 614/38402 to the database
# Added chunk 615/38402 to the database
# Added chunk 616/38402 to the database
# Added chunk 617/38402 to the database
# Added chunk 618/38402 to the database
# Added chunk 619/38402 to the database
# Added chunk 620/38402 to the database
# Added chunk 621/38402 to the database
# Added chunk 622/38402 to the database
# Added chunk 623/38402 to the database
# Added chunk 624/38402 to the database
# Added chunk 625/38402 to the database
# Added chunk 626/38402 to the database
# Added chunk 627/38402 to the database
# Added chunk 628/38402 to the database
# Added chunk 629/38402 to the database
# Added chunk 630/38402 to the database
# Added chunk 631/38402 to the database
# Added chunk 632/38402 to the database
# Added chunk 633/38402 to the database
# Added chunk 634/38402 to the database
# Added chunk 635/38402 to the database
# Added chunk 636/38402 to the database
# Added chunk 637/38402 to the database
# Added chunk 638/38402 to the database
# Added chunk 639/38402 to the database
# Added chunk 640/38402 to the database
# Added chunk 641/38402 to the database
# Added chunk 642/38402 to the database
# Added chunk 643/38402 to the database
# Added chunk 644/38402 to the database
# Added chunk 645/38402 to the database
# Added chunk 646/38402 to the database
# Added chunk 647/38402 to the database
# Added chunk 648/38402 to the database
# Added chunk 649/38402 to the database
# Added chunk 650/38402 to the database
# Added chunk 651/38402 to the database
# Added chunk 652/38402 to the database
# Added chunk 653/38402 to the database
# Added chunk 654/38402 to the database
# Added chunk 655/38402 to the database
# Added chunk 656/38402 to the database
# Added chunk 657/38402 to the database
# Added chunk 658/38402 to the database
# Added chunk 659/38402 to the database
# Added chunk 660/38402 to the database
# Added chunk 661/38402 to the database
# Added chunk 662/38402 to the database
# Added chunk 663/38402 to the database
# Added chunk 664/38402 to the database
# Added chunk 665/38402 to the database
# Added chunk 666/38402 to the database
# Added chunk 667/38402 to the database
# Added chunk 668/38402 to the database
# Added chunk 669/38402 to the database
# Added chunk 670/38402 to the database
# Added chunk 671/38402 to the database
# Added chunk 672/38402 to the database
# Added chunk 673/38402 to the database
# Added chunk 674/38402 to the database
# Added chunk 675/38402 to the database
# Added chunk 676/38402 to the database
# Added chunk 677/38402 to the database
# Added chunk 678/38402 to the database
# Added chunk 679/38402 to the database
# Added chunk 680/38402 to the database
# Added chunk 681/38402 to the database
# Added chunk 682/38402 to the database
# Added chunk 683/38402 to the database
# Added chunk 684/38402 to the database
# Added chunk 685/38402 to the database
# Added chunk 686/38402 to the database
# Added chunk 687/38402 to the database
# Added chunk 688/38402 to the database
# Added chunk 689/38402 to the database
# Added chunk 690/38402 to the database
# Added chunk 691/38402 to the database
# Added chunk 692/38402 to the database
# Added chunk 693/38402 to the database
# Added chunk 694/38402 to the database
# Added chunk 695/38402 to the database
# Added chunk 696/38402 to the database
# Added chunk 697/38402 to the database
# Added chunk 698/38402 to the database
# Added chunk 699/38402 to the database
# Added chunk 700/38402 to the database
# Added chunk 701/38402 to the database
# Added chunk 702/38402 to the database
# Added chunk 703/38402 to the database
# Added chunk 704/38402 to the database
# Added chunk 705/38402 to the database
# Added chunk 706/38402 to the database
# Added chunk 707/38402 to the database
# Added chunk 708/38402 to the database
# Added chunk 709/38402 to the database
# Added chunk 710/38402 to the database
# Added chunk 711/38402 to the database
# Added chunk 712/38402 to the database
# Added chunk 713/38402 to the database
# Added chunk 714/38402 to the database
# Added chunk 715/38402 to the database
# Added chunk 716/38402 to the database
# Added chunk 717/38402 to the database
# Added chunk 718/38402 to the database
# Added chunk 719/38402 to the database
# Added chunk 720/38402 to the database
# Added chunk 721/38402 to the database
# Added chunk 722/38402 to the database
# Added chunk 723/38402 to the database
# Added chunk 724/38402 to the database
# Added chunk 725/38402 to the database
# Added chunk 726/38402 to the database
# Added chunk 727/38402 to the database
# Added chunk 728/38402 to the database
# Added chunk 729/38402 to the database
# Added chunk 730/38402 to the database
# Added chunk 731/38402 to the database
# Added chunk 732/38402 to the database
# Added chunk 733/38402 to the database
# Added chunk 734/38402 to the database
# Added chunk 735/38402 to the database
# Added chunk 736/38402 to the database
# Added chunk 737/38402 to the database
# Added chunk 738/38402 to the database
# Added chunk 739/38402 to the database
# Added chunk 740/38402 to the database
# Added chunk 741/38402 to the database
# Added chunk 742/38402 to the database
# Added chunk 743/38402 to the database
# Added chunk 744/38402 to the database
# Added chunk 745/38402 to the database
# Added chunk 746/38402 to the database
# Added chunk 747/38402 to the database
# Added chunk 748/38402 to the database
# Added chunk 749/38402 to the database
# Added chunk 750/38402 to the database
# Added chunk 751/38402 to the database
# Added chunk 752/38402 to the database
# Added chunk 753/38402 to the database
# Added chunk 754/38402 to the database
# Added chunk 755/38402 to the database
# Added chunk 756/38402 to the database
# Added chunk 757/38402 to the database
# Added chunk 758/38402 to the database
# Added chunk 759/38402 to the database
# Added chunk 760/38402 to the database
# Added chunk 761/38402 to the database
# Added chunk 762/38402 to the database
# Added chunk 763/38402 to the database
# Added chunk 764/38402 to the database
# Added chunk 765/38402 to the database
# Added chunk 766/38402 to the database
# Added chunk 767/38402 to the database
# Added chunk 768/38402 to the database
# Added chunk 769/38402 to the database
# Added chunk 770/38402 to the database
# Added chunk 771/38402 to the database
# Added chunk 772/38402 to the database
# Added chunk 773/38402 to the database
# Added chunk 774/38402 to the database
# Added chunk 775/38402 to the database
# Added chunk 776/38402 to the database
# Added chunk 777/38402 to the database
# Added chunk 778/38402 to the database
# Added chunk 779/38402 to the database
# Added chunk 780/38402 to the database
# Added chunk 781/38402 to the database
# Added chunk 782/38402 to the database
# Added chunk 783/38402 to the database
# Added chunk 784/38402 to the database
# Added chunk 785/38402 to the database
# Added chunk 786/38402 to the database
# Added chunk 787/38402 to the database
# Added chunk 788/38402 to the database
# Added chunk 789/38402 to the database
# Added chunk 790/38402 to the database
# Added chunk 791/38402 to the database
# Added chunk 792/38402 to the database
# Added chunk 793/38402 to the database
# Added chunk 794/38402 to the database
# Added chunk 795/38402 to the database
# Added chunk 796/38402 to the database
# Added chunk 797/38402 to the database
# Added chunk 798/38402 to the database
# Added chunk 799/38402 to the database
# Added chunk 800/38402 to the database
# Added chunk 801/38402 to the database
# Added chunk 802/38402 to the database
# Added chunk 803/38402 to the database
# Added chunk 804/38402 to the database
# Added chunk 805/38402 to the database
# Added chunk 806/38402 to the database
# Added chunk 807/38402 to the database
# Added chunk 808/38402 to the database
# Added chunk 809/38402 to the database
# Added chunk 810/38402 to the database
# Added chunk 811/38402 to the database
# Added chunk 812/38402 to the database
# Added chunk 813/38402 to the database
# Added chunk 814/38402 to the database
# Added chunk 815/38402 to the database
# Added chunk 816/38402 to the database
# Added chunk 817/38402 to the database
# Added chunk 818/38402 to the database
# Added chunk 819/38402 to the database
# Added chunk 820/38402 to the database
# Added chunk 821/38402 to the database
# Added chunk 822/38402 to the database
# Added chunk 823/38402 to the database
# Added chunk 824/38402 to the database
# Added chunk 825/38402 to the database
# Added chunk 826/38402 to the database
# Added chunk 827/38402 to the database
# Added chunk 828/38402 to the database
# Added chunk 829/38402 to the database
# Added chunk 830/38402 to the database
# Added chunk 831/38402 to the database
# Added chunk 832/38402 to the database
# Added chunk 833/38402 to the database
# Added chunk 834/38402 to the database
# Added chunk 835/38402 to the database
# Added chunk 836/38402 to the database
# Added chunk 837/38402 to the database
# Added chunk 838/38402 to the database
# Added chunk 839/38402 to the database
# Added chunk 840/38402 to the database
# Added chunk 841/38402 to the database
# Added chunk 842/38402 to the database
# Added chunk 843/38402 to the database
# Added chunk 844/38402 to the database
# Added chunk 845/38402 to the database
# Added chunk 846/38402 to the database
# Added chunk 847/38402 to the database
# Added chunk 848/38402 to the database
# Added chunk 849/38402 to the database
# Added chunk 850/38402 to the database
# Added chunk 851/38402 to the database
# Added chunk 852/38402 to the database
# Added chunk 853/38402 to the database
# Added chunk 854/38402 to the database
# Added chunk 855/38402 to the database
# Added chunk 856/38402 to the database
# Added chunk 857/38402 to the database
# Added chunk 858/38402 to the database
# Added chunk 859/38402 to the database
# Added chunk 860/38402 to the database
# Added chunk 861/38402 to the database
# Added chunk 862/38402 to the database
# Added chunk 863/38402 to the database
# Added chunk 864/38402 to the database
# Added chunk 865/38402 to the database
# Added chunk 866/38402 to the database
# Added chunk 867/38402 to the database
# Added chunk 868/38402 to the database
# Added chunk 869/38402 to the database
# Added chunk 870/38402 to the database
# Added chunk 871/38402 to the database
# Added chunk 872/38402 to the database
# Added chunk 873/38402 to the database
# Added chunk 874/38402 to the database
# Added chunk 875/38402 to the database
# Added chunk 876/38402 to the database
# Added chunk 877/38402 to the database
# Added chunk 878/38402 to the database
# Added chunk 879/38402 to the database
# Added chunk 880/38402 to the database
# Added chunk 881/38402 to the database
# Added chunk 882/38402 to the database
# Added chunk 883/38402 to the database
# Added chunk 884/38402 to the database
# Added chunk 885/38402 to the database
# Added chunk 886/38402 to the database
# Added chunk 887/38402 to the database
# Added chunk 888/38402 to the database
# Added chunk 889/38402 to the database
# Added chunk 890/38402 to the database
# Added chunk 891/38402 to the database
# Added chunk 892/38402 to the database
# Added chunk 893/38402 to the database
# Added chunk 894/38402 to the database
# Added chunk 895/38402 to the database
# Added chunk 896/38402 to the database
# Added chunk 897/38402 to the database
# Added chunk 898/38402 to the database
# Added chunk 899/38402 to the database
# Added chunk 900/38402 to the database
# Added chunk 901/38402 to the database
# Added chunk 902/38402 to the database
# Added chunk 903/38402 to the database
# Added chunk 904/38402 to the database
# Added chunk 905/38402 to the database
# Added chunk 906/38402 to the database
# Added chunk 907/38402 to the database
# Added chunk 908/38402 to the database
# Added chunk 909/38402 to the database
# Added chunk 910/38402 to the database
# Added chunk 911/38402 to the database
# Added chunk 912/38402 to the database
# Added chunk 913/38402 to the database
# Added chunk 914/38402 to the database
# Added chunk 915/38402 to the database
# Added chunk 916/38402 to the database
# Added chunk 917/38402 to the database
# Added chunk 918/38402 to the database
# Added chunk 919/38402 to the database
# Added chunk 920/38402 to the database
# Added chunk 921/38402 to the database
# Added chunk 922/38402 to the database
# Added chunk 923/38402 to the database
# Added chunk 924/38402 to the database
# Added chunk 925/38402 to the database
# Added chunk 926/38402 to the database
# Added chunk 927/38402 to the database
# Added chunk 928/38402 to the database
# Added chunk 929/38402 to the database
# Added chunk 930/38402 to the database
# Added chunk 931/38402 to the database
# Added chunk 932/38402 to the database
# Added chunk 933/38402 to the database
# Added chunk 934/38402 to the database
# Added chunk 935/38402 to the database
# Added chunk 936/38402 to the database
# Added chunk 937/38402 to the database
# Added chunk 938/38402 to the database
# Added chunk 939/38402 to the database
# Added chunk 940/38402 to the database
# Added chunk 941/38402 to the database
# Added chunk 942/38402 to the database
# Added chunk 943/38402 to the database
# Added chunk 944/38402 to the database
# Added chunk 945/38402 to the database
# Added chunk 946/38402 to the database
# Added chunk 947/38402 to the database
# Added chunk 948/38402 to the database
# Added chunk 949/38402 to the database
# Added chunk 950/38402 to the database
# Added chunk 951/38402 to the database
# Added chunk 952/38402 to the database
# Added chunk 953/38402 to the database
# Added chunk 954/38402 to the database
# Added chunk 955/38402 to the database
# Added chunk 956/38402 to the database
# Added chunk 957/38402 to the database
# Added chunk 958/38402 to the database
# Added chunk 959/38402 to the database
# Added chunk 960/38402 to the database
# Added chunk 961/38402 to the database
# Added chunk 962/38402 to the database
# Added chunk 963/38402 to the database
# Added chunk 964/38402 to the database
# Added chunk 965/38402 to the database
# Added chunk 966/38402 to the database
# Added chunk 967/38402 to the database
# Added chunk 968/38402 to the database
# Added chunk 969/38402 to the database
# Added chunk 970/38402 to the database
# Added chunk 971/38402 to the database
# Added chunk 972/38402 to the database
# Added chunk 973/38402 to the database
# Added chunk 974/38402 to the database
# Added chunk 975/38402 to the database
# Added chunk 976/38402 to the database
# Added chunk 977/38402 to the database
# Added chunk 978/38402 to the database
# Added chunk 979/38402 to the database
# Added chunk 980/38402 to the database
# Added chunk 981/38402 to the database
# Added chunk 982/38402 to the database
# Added chunk 983/38402 to the database
# Added chunk 984/38402 to the database
# Added chunk 985/38402 to the database
# Added chunk 986/38402 to the database
# Added chunk 987/38402 to the database
# Added chunk 988/38402 to the database
# Added chunk 989/38402 to the database
# Added chunk 990/38402 to the database
# Added chunk 991/38402 to the database
# Added chunk 992/38402 to the database
# Added chunk 993/38402 to the database
# Added chunk 994/38402 to the database
# Added chunk 995/38402 to the database
# Added chunk 996/38402 to the database
# Added chunk 997/38402 to the database
# Added chunk 998/38402 to the database
# Added chunk 999/38402 to the database
# Added chunk 1000/38402 to the database
# Added chunk 1001/38402 to the database
# Added chunk 1002/38402 to the database
# Added chunk 1003/38402 to the database
# Added chunk 1004/38402 to the database
# Added chunk 1005/38402 to the database
# Added chunk 1006/38402 to the database
# Added chunk 1007/38402 to the database
# Added chunk 1008/38402 to the database
# Added chunk 1009/38402 to the database
# Added chunk 1010/38402 to the database
# Added chunk 1011/38402 to the database
# Added chunk 1012/38402 to the database
# Added chunk 1013/38402 to the database
# Added chunk 1014/38402 to the database
# Added chunk 1015/38402 to the database
# Added chunk 1016/38402 to the database
# Added chunk 1017/38402 to the database
# Added chunk 1018/38402 to the database
# Added chunk 1019/38402 to the database
# Added chunk 1020/38402 to the database
# Added chunk 1021/38402 to the database
# Added chunk 1022/38402 to the database
# Added chunk 1023/38402 to the database
# Added chunk 1024/38402 to the database
# Added chunk 1025/38402 to the database
# Added chunk 1026/38402 to the database
# Added chunk 1027/38402 to the database
# Added chunk 1028/38402 to the database
# Added chunk 1029/38402 to the database
# Added chunk 1030/38402 to the database
# Added chunk 1031/38402 to the database
# Added chunk 1032/38402 to the database
# Added chunk 1033/38402 to the database
# Added chunk 1034/38402 to the database
# Added chunk 1035/38402 to the database
# Added chunk 1036/38402 to the database
# Added chunk 1037/38402 to the database
# Added chunk 1038/38402 to the database
# Added chunk 1039/38402 to the database
# Added chunk 1040/38402 to the database
# Added chunk 1041/38402 to the database
# Added chunk 1042/38402 to the database
# Added chunk 1043/38402 to the database
# Added chunk 1044/38402 to the database
# Added chunk 1045/38402 to the database
# Added chunk 1046/38402 to the database
# Added chunk 1047/38402 to the database
# Added chunk 1048/38402 to the database
# Added chunk 1049/38402 to the database
# Added chunk 1050/38402 to the database
# Added chunk 1051/38402 to the database
# Added chunk 1052/38402 to the database
# Added chunk 1053/38402 to the database
# Added chunk 1054/38402 to the database
# Added chunk 1055/38402 to the database
# Added chunk 1056/38402 to the database
# Added chunk 1057/38402 to the database
# Added chunk 1058/38402 to the database
# Added chunk 1059/38402 to the database
# Added chunk 1060/38402 to the database
# Added chunk 1061/38402 to the database
# Added chunk 1062/38402 to the database
# Added chunk 1063/38402 to the database
# Added chunk 1064/38402 to the database
# Added chunk 1065/38402 to the database
# Added chunk 1066/38402 to the database
# Added chunk 1067/38402 to the database
# Added chunk 1068/38402 to the database
# Added chunk 1069/38402 to the database
# Added chunk 1070/38402 to the database
# Added chunk 1071/38402 to the database
# Added chunk 1072/38402 to the database
# Added chunk 1073/38402 to the database
# Added chunk 1074/38402 to the database
# Added chunk 1075/38402 to the database
# Added chunk 1076/38402 to the database
# Added chunk 1077/38402 to the database
# Added chunk 1078/38402 to the database
# Added chunk 1079/38402 to the database
# Added chunk 1080/38402 to the database
# Added chunk 1081/38402 to the database
# Added chunk 1082/38402 to the database
# Added chunk 1083/38402 to the database
# Added chunk 1084/38402 to the database
# Added chunk 1085/38402 to the database
# Added chunk 1086/38402 to the database
# Added chunk 1087/38402 to the database
# Added chunk 1088/38402 to the database
# Added chunk 1089/38402 to the database
# Added chunk 1090/38402 to the database
# Added chunk 1091/38402 to the database
# Added chunk 1092/38402 to the database
# Added chunk 1093/38402 to the database
# Added chunk 1094/38402 to the database
# Added chunk 1095/38402 to the database
# Added chunk 1096/38402 to the database
# Added chunk 1097/38402 to the database
# Added chunk 1098/38402 to the database
# Added chunk 1099/38402 to the database
# Added chunk 1100/38402 to the database
# Added chunk 1101/38402 to the database
# Added chunk 1102/38402 to the database
# Added chunk 1103/38402 to the database
# Added chunk 1104/38402 to the database
# Added chunk 1105/38402 to the database
# Added chunk 1106/38402 to the database
# Added chunk 1107/38402 to the database
# Added chunk 1108/38402 to the database
# Added chunk 1109/38402 to the database
# Added chunk 1110/38402 to the database
# Added chunk 1111/38402 to the database
# Added chunk 1112/38402 to the database
# Added chunk 1113/38402 to the database
# Added chunk 1114/38402 to the database
# Added chunk 1115/38402 to the database
# Added chunk 1116/38402 to the database
# Added chunk 1117/38402 to the database
# Added chunk 1118/38402 to the database
# Added chunk 1119/38402 to the database
# Added chunk 1120/38402 to the database
# Added chunk 1121/38402 to the database
# Added chunk 1122/38402 to the database
# Added chunk 1123/38402 to the database
# Added chunk 1124/38402 to the database
# Added chunk 1125/38402 to the database
# Added chunk 1126/38402 to the database
# Added chunk 1127/38402 to the database
# Added chunk 1128/38402 to the database
# Added chunk 1129/38402 to the database
# Added chunk 1130/38402 to the database
# Added chunk 1131/38402 to the database
# Added chunk 1132/38402 to the database
# Added chunk 1133/38402 to the database
# Added chunk 1134/38402 to the database
# Added chunk 1135/38402 to the database
# Added chunk 1136/38402 to the database
# Added chunk 1137/38402 to the database
# Added chunk 1138/38402 to the database
# Added chunk 1139/38402 to the database
# Added chunk 1140/38402 to the database
# Added chunk 1141/38402 to the database
# Added chunk 1142/38402 to the database
# Added chunk 1143/38402 to the database
# Added chunk 1144/38402 to the database
# Added chunk 1145/38402 to the database
# Added chunk 1146/38402 to the database
# Added chunk 1147/38402 to the database
# Added chunk 1148/38402 to the database
# Added chunk 1149/38402 to the database
# Added chunk 1150/38402 to the database
# Added chunk 1151/38402 to the database
# Added chunk 1152/38402 to the database
# Added chunk 1153/38402 to the database
# Added chunk 1154/38402 to the database
# Added chunk 1155/38402 to the database
# Added chunk 1156/38402 to the database
# Added chunk 1157/38402 to the database
# Added chunk 1158/38402 to the database
# Added chunk 1159/38402 to the database
# Added chunk 1160/38402 to the database
# Added chunk 1161/38402 to the database
# Added chunk 1162/38402 to the database
# Added chunk 1163/38402 to the database
# Added chunk 1164/38402 to the database
# Added chunk 1165/38402 to the database
# Added chunk 1166/38402 to the database
# Added chunk 1167/38402 to the database
# Added chunk 1168/38402 to the database
# Added chunk 1169/38402 to the database
# Added chunk 1170/38402 to the database
# Added chunk 1171/38402 to the database
# Added chunk 1172/38402 to the database
# Added chunk 1173/38402 to the database
# Added chunk 1174/38402 to the database
# Added chunk 1175/38402 to the database
# Added chunk 1176/38402 to the database
# Added chunk 1177/38402 to the database
# Added chunk 1178/38402 to the database
# Added chunk 1179/38402 to the database
# Added chunk 1180/38402 to the database
# Added chunk 1181/38402 to the database
# Added chunk 1182/38402 to the database
# Added chunk 1183/38402 to the database
# Added chunk 1184/38402 to the database
# Added chunk 1185/38402 to the database
# Added chunk 1186/38402 to the database
# Added chunk 1187/38402 to the database
# Added chunk 1188/38402 to the database
# Added chunk 1189/38402 to the database
# Added chunk 1190/38402 to the database
# Added chunk 1191/38402 to the database
# Added chunk 1192/38402 to the database
# Added chunk 1193/38402 to the database
# Added chunk 1194/38402 to the database
# Added chunk 1195/38402 to the database
# Added chunk 1196/38402 to the database
# Added chunk 1197/38402 to the database
# Added chunk 1198/38402 to the database
# Added chunk 1199/38402 to the database
# Added chunk 1200/38402 to the database
# Added chunk 1201/38402 to the database
# Added chunk 1202/38402 to the database
# Added chunk 1203/38402 to the database
# Added chunk 1204/38402 to the database
# Added chunk 1205/38402 to the database
# Added chunk 1206/38402 to the database
# Added chunk 1207/38402 to the database
# Added chunk 1208/38402 to the database
# Added chunk 1209/38402 to the database
# Added chunk 1210/38402 to the database
# Added chunk 1211/38402 to the database
# Added chunk 1212/38402 to the database
# Added chunk 1213/38402 to the database
# Added chunk 1214/38402 to the database
# Added chunk 1215/38402 to the database
# Added chunk 1216/38402 to the database
# Added chunk 1217/38402 to the database
# Added chunk 1218/38402 to the database
# Added chunk 1219/38402 to the database
# Added chunk 1220/38402 to the database
# Added chunk 1221/38402 to the database
# Added chunk 1222/38402 to the database
# Added chunk 1223/38402 to the database
# Added chunk 1224/38402 to the database
# Added chunk 1225/38402 to the database
# Added chunk 1226/38402 to the database
# Added chunk 1227/38402 to the database
# Added chunk 1228/38402 to the database
# Added chunk 1229/38402 to the database
# Added chunk 1230/38402 to the database
# Added chunk 1231/38402 to the database
# Added chunk 1232/38402 to the database
# Added chunk 1233/38402 to the database
# Added chunk 1234/38402 to the database
# Added chunk 1235/38402 to the database
# Added chunk 1236/38402 to the database
# Added chunk 1237/38402 to the database
# Added chunk 1238/38402 to the database
# Added chunk 1239/38402 to the database
# Added chunk 1240/38402 to the database
# Added chunk 1241/38402 to the database
# Added chunk 1242/38402 to the database
# Added chunk 1243/38402 to the database
# Added chunk 1244/38402 to the database
# Added chunk 1245/38402 to the database
# Added chunk 1246/38402 to the database
# Added chunk 1247/38402 to the database
# Added chunk 1248/38402 to the database
# Added chunk 1249/38402 to the database
# Added chunk 1250/38402 to the database
# Added chunk 1251/38402 to the database
# Added chunk 1252/38402 to the database
# Added chunk 1253/38402 to the database
# Added chunk 1254/38402 to the database
# Added chunk 1255/38402 to the database
# Added chunk 1256/38402 to the database
# Added chunk 1257/38402 to the database
# Added chunk 1258/38402 to the database
# Added chunk 1259/38402 to the database
# ...
# Added chunk 1768/38402 to the database
# Added chunk 1769/38402 to the database
# Added chunk 1770/38402 to the database
# Added chunk 1771/38402 to the database
# Added chunk 1772/38402 to the database
# Added chunk 1773/38402 to the database
# Added chunk 1774/38402 to the database
# Added chunk 1775/38402 to the database
# Added chunk 1776/38402 to the database
# Added chunk 1777/38402 to the database
# Added chunk 1778/38402 to the database
# Added chunk 1779/38402 to the database
# Added chunk 1780/38402 to the database
# Added chunk 1781/38402 to the database
# Added chunk 1782/38402 to the database
# Added chunk 1783/38402 to the database
# Added chunk 1784/38402 to the database
# Added chunk 1785/38402 to the database
# Added chunk 1786/38402 to the database
# Added chunk 1787/38402 to the database
# Added chunk 1788/38402 to the database
# Added chunk 1789/38402 to the database
# Added chunk 1790/38402 to the database
# Added chunk 1791/38402 to the database
# Added chunk 1792/38402 to the database
# Added chunk 1793/38402 to the database
# Added chunk 1794/38402 to the database
# Added chunk 1795/38402 to the database
# Added chunk 1796/38402 to the database
# Added chunk 1797/38402 to the database
# Added chunk 1798/38402 to the database
# Added chunk 1799/38402 to the database
# Added chunk 1800/38402 to the database
# Added chunk 1801/38402 to the database
# Added chunk 1802/38402 to the database
# Added chunk 1803/38402 to the database
# Added chunk 1804/38402 to the database
# Added chunk 1805/38402 to the database
# Added chunk 1806/38402 to the database
# Added chunk 1807/38402 to the database
# Added chunk 1808/38402 to the database
# Added chunk 1809/38402 to the database
# Added chunk 1810/38402 to the database
# Added chunk 1811/38402 to the database
# Added chunk 1812/38402 to the database
# Added chunk 1813/38402 to the database
# Added chunk 1814/38402 to the database
# Added chunk 1815/38402 to the database
# Added chunk 1816/38402 to the database
# Added chunk 1817/38402 to the database
# Added chunk 1818/38402 to the database
# Added chunk 1819/38402 to the database
# Added chunk 1820/38402 to the database
# Added chunk 1821/38402 to the database
# Added chunk 1822/38402 to the database
# Added chunk 1823/38402 to the database
# Added chunk 1824/38402 to the database
# Added chunk 1825/38402 to the database
# Added chunk 1826/38402 to the database
# Added chunk 1827/38402 to the database
# Added chunk 1828/38402 to the database
# Added chunk 1829/38402 to the database
# Added chunk 1830/38402 to the database
# Added chunk 1831/38402 to the database
# Added chunk 1832/38402 to the database
# Added chunk 1833/38402 to the database
# Added chunk 1834/38402 to the database
# Added chunk 1835/38402 to the database
# Added chunk 1836/38402 to the database
# Added chunk 1837/38402 to the database
# Added chunk 1838/38402 to the database
# Added chunk 1839/38402 to the database
# Added chunk 1840/38402 to the database
# Added chunk 1841/38402 to the database
# Added chunk 1842/38402 to the database
# Added chunk 1843/38402 to the database
# Added chunk 1844/38402 to the database
# Added chunk 1845/38402 to the database
# Added chunk 1846/38402 to the database
# Added chunk 1847/38402 to the database
# Added chunk 1848/38402 to the database
# Added chunk 1849/38402 to the database
# Added chunk 1850/38402 to the database
# Added chunk 1851/38402 to the database
# Added chunk 1852/38402 to the database
# Added chunk 1853/38402 to the database
# Added chunk 1854/38402 to the database
# Added chunk 1855/38402 to the database
# Added chunk 1856/38402 to the database
# Added chunk 1857/38402 to the database
# Added chunk 1858/38402 to the database
# Added chunk 1859/38402 to the database
# Added chunk 1860/38402 to the database
# Added chunk 1861/38402 to the database
# Added chunk 1862/38402 to the database
# Added chunk 1863/38402 to the database
# Added chunk 1864/38402 to the database
# Added chunk 1865/38402 to the database
# Added chunk 1866/38402 to the database
# Added chunk 1867/38402 to the database
# Added chunk 1868/38402 to the database
# Added chunk 1869/38402 to the database
# Added chunk 1870/38402 to the database
# Added chunk 1871/38402 to the database
# Added chunk 1872/38402 to the database
# Added chunk 1873/38402 to the database
# Added chunk 1874/38402 to the database
# Added chunk 1875/38402 to the database
# Added chunk 1876/38402 to the database
# Added chunk 1877/38402 to the database
# Added chunk 1878/38402 to the database
# Added chunk 1879/38402 to the database
# Added chunk 1880/38402 to the database
# Added chunk 1881/38402 to the database
# Added chunk 1882/38402 to the database
# Added chunk 1883/38402 to the database
# Added chunk 1884/38402 to the database
# Added chunk 1885/38402 to the database
# Added chunk 1886/38402 to the database
# Added chunk 1887/38402 to the database
# Added chunk 1888/38402 to the database
# Added chunk 1889/38402 to the database
# Added chunk 1890/38402 to the database
# Added chunk 1891/38402 to the database
# Added chunk 1892/38402 to the database
# Added chunk 1893/38402 to the database
# Added chunk 1894/38402 to the database
# Added chunk 1895/38402 to the database
# Added chunk 1896/38402 to the database
# Added chunk 1897/38402 to the database
# Added chunk 1898/38402 to the database
# Added chunk 1899/38402 to the database
# Added chunk 1900/38402 to the database
# Added chunk 1901/38402 to the database
# Added chunk 1902/38402 to the database
# Added chunk 1903/38402 to the database
# Added chunk 1904/38402 to the database
# Added chunk 1905/38402 to the database
# Added chunk 1906/38402 to the database
# Added chunk 1907/38402 to the database
# Added chunk 1908/38402 to the database
# Added chunk 1909/38402 to the database
# Added chunk 1910/38402 to the database
# Added chunk 1911/38402 to the database
# Added chunk 1912/38402 to the database
# Added chunk 1913/38402 to the database
# Added chunk 1914/38402 to the database
# Added chunk 1915/38402 to the database
# Added chunk 1916/38402 to the database
# Added chunk 1917/38402 to the database
# Added chunk 1918/38402 to the database
# Added chunk 1919/38402 to the database
# Added chunk 1920/38402 to the database
# Added chunk 1921/38402 to the database
# Added chunk 1922/38402 to the database
# Added chunk 1923/38402 to the database
# Added chunk 1924/38402 to the database
# Added chunk 1925/38402 to the database
# Added chunk 1926/38402 to the database
# Added chunk 1927/38402 to the database
# Added chunk 1928/38402 to the database
# Added chunk 1929/38402 to the database
# Added chunk 1930/38402 to the database
# Added chunk 1931/38402 to the database
# Added chunk 1932/38402 to the database
# Added chunk 1933/38402 to the database
# Added chunk 1934/38402 to the database
# Added chunk 1935/38402 to the database
# Added chunk 1936/38402 to the database
# Added chunk 1937/38402 to the database
# Added chunk 1938/38402 to the database
# Added chunk 1939/38402 to the database
# Added chunk 1940/38402 to the database
# Added chunk 1941/38402 to the database
# Added chunk 1942/38402 to the database
# Added chunk 1943/38402 to the database
# Added chunk 1944/38402 to the database
# Added chunk 1945/38402 to the database
# Added chunk 1946/38402 to the database
# Added chunk 1947/38402 to the database
# Added chunk 1948/38402 to the database
# Added chunk 1949/38402 to the database
# Added chunk 1950/38402 to the database
# Added chunk 1951/38402 to the database
# Added chunk 1952/38402 to the database
# Added chunk 1953/38402 to the database
# Added chunk 1954/38402 to the database
# Added chunk 1955/38402 to the database
# Added chunk 1956/38402 to the database
# Added chunk 1957/38402 to the database
# Added chunk 1958/38402 to the database
# Added chunk 1959/38402 to the database
# Added chunk 1960/38402 to the database
# Added chunk 1961/38402 to the database
# Added chunk 1962/38402 to the database
# Added chunk 1963/38402 to the database
# Added chunk 1964/38402 to the database
# Added chunk 1965/38402 to the database
# Added chunk 1966/38402 to the database
# Added chunk 1967/38402 to the database
# Added chunk 1968/38402 to the database
# Added chunk 1969/38402 to the database
# Added chunk 1970/38402 to the database
# Added chunk 1971/38402 to the database
# Added chunk 1972/38402 to the database
# Added chunk 1973/38402 to the database
# Added chunk 1974/38402 to the database
# Added chunk 1975/38402 to the database
# Added chunk 1976/38402 to the database
# Added chunk 1977/38402 to the database
# Added chunk 1978/38402 to the database
# Added chunk 1979/38402 to the database
# Added chunk 1980/38402 to the database
# Added chunk 1981/38402 to the database
# Added chunk 1982/38402 to the database
# Added chunk 1983/38402 to the database
# Added chunk 1984/38402 to the database
# Added chunk 1985/38402 to the database
# Added chunk 1986/38402 to the database
# Added chunk 1987/38402 to the database
# Added chunk 1988/38402 to the database
# Added chunk 1989/38402 to the database
# Added chunk 1990/38402 to the database
# Added chunk 1991/38402 to the database
# Added chunk 1992/38402 to the database
# Added chunk 1993/38402 to the database
# Added chunk 1994/38402 to the database
# Added chunk 1995/38402 to the database
# Added chunk 1996/38402 to the database
# Added chunk 1997/38402 to the database
# Added chunk 1998/38402 to the database
# Added chunk 1999/38402 to the database
# Added chunk 2000/38402 to the database
# Added chunk 2001/38402 to the database
# Added chunk 2002/38402 to the database
# Added chunk 2003/38402 to the database
# Added chunk 2004/38402 to the database
# Added chunk 2005/38402 to the database
# Added chunk 2006/38402 to the database
# Added chunk 2007/38402 to the database
# Added chunk 2008/38402 to the database
# Added chunk 2009/38402 to the database
# Added chunk 2010/38402 to the database
# Added chunk 2011/38402 to the database
# Added chunk 2012/38402 to the database
# Added chunk 2013/38402 to the database
# Added chunk 2014/38402 to the database
# Added chunk 2015/38402 to the database
# Added chunk 2016/38402 to the database
# Added chunk 2017/38402 to the database
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for i, chunk in enumerate(dataset):
# ----> 2   add_chunk_to_database(chunk)
#       3   print(f'Added chunk {i+1}/{len(dataset)} to the database\r')
#
# Cell In[10], line 11, in add_chunk_to_database(chunk)
#      10 def add_chunk_to_database(chunk):
# ---> 11   embedding = get_embedding(chunk)
#      12   VECTOR_DB.append((chunk, embedding))
#
# Cell In[7], line 12, in get_embedding(text)
#       6 headers = {"Content-Type": "application/json"}
#       7 data = {
#       8     "model": "text-embedding-conan-embedding-v1",
#       9     "input": text
#      10 }
# ---> 12 response = requests.post(url, headers=headers, json=data)
#      13 if response.status_code == 200:
#      14     # 从响应中提取embedding向量
#      15     result = response.json()
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\seia\.local\share\mamba\envs\seia\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def cosine_similarity(a, b):
  dot_product = sum([x * y for x, y in zip(a, b)])
  norm_a = sum([x ** 2 for x in a]) ** 0.5
  norm_b = sum([x ** 2 for x in b]) ** 0.5
  return dot_product / (norm_a * norm_b)

# %%
def retrieve(query, top_n=3):
  query_embedding = get_embedding(query)
  # temporary list to store (chunk, similarity) pairs
  similarities = []
  for chunk, embedding in VECTOR_DB:
    similarity = cosine_similarity(query_embedding, embedding)
    similarities.append((chunk, similarity))
  # sort by similarity in descending order, because higher similarity means more relevant chunks
  similarities.sort(key=lambda x: x[1], reverse=True)
  # finally, return the top N most relevant chunks
  return similarities[:top_n]

# %%
input_query = input('Ask me a question: ')
retrieved_knowledge = retrieve(input_query, top_n=30)

print('Retrieved knowledge:')
for chunk, similarity in retrieved_knowledge:
  print(f' - (similarity: {similarity:.2f}) {chunk}')

instruction_prompt = f'''You are a helpful chatbot.
Use only the following pieces of context to answer the question. Don't make up any new information:
{'\n'.join([f' - {chunk}' for chunk, similarity in retrieved_knowledge])}
'''
# Out:
# Retrieved knowledge:
#  - (similarity: 0.66) [unknown_chara_602628616]: （在阿拜多斯住宅区遇见了熟悉的面孔）
#
#  - (similarity: 0.66) 无月: 那些是阿拜多斯的人哦。
#
#  - (similarity: 0.64) 绫音: 我们是阿拜多斯对策委员会。
#
#  - (similarity: 0.63) 白子: 你是来找「阿拜多斯」的吗？
#
#  - (similarity: 0.63) 头盔团B: ……没错。他是阿拜多斯对策委员会的成员。
#
#  - (similarity: 0.63) 无月: 是吧，是阿拜多斯那些孩子……虽然也有不认识的人。<br/>……他们在这里做什么？而且还戴着面罩。
#
#  - (similarity: 0.63) 亚瑠: 骗，骗人的吧……那些孩子竟然是阿拜多斯……？<br/>呜，呜呜……命运为什么要开这种玩笑……
#
#  - (similarity: 0.62) 伊织: 嗯？那边的学生？我记得是……阿拜多斯？
#
#  - (similarity: 0.62) 佳世子: 但反过来说，阿拜多斯就是那么不容忽视的对手。<br/>虽然他们有学生数量少这个最大的弱点。
#
#  - (similarity: 0.60) ???: 换句话说就是你们被解雇了。<br/>从今以后，阿拜多斯由我们来处理。
#
#  - (similarity: 0.60) 黑色西装人: ……呵呵，因为情况有所变动。 <br/>所以我想再次向持有阿拜多斯最高神秘的星野小姐提议。
#
#  - (similarity: 0.60) 佳世子: 阿……阿拜多斯……？
#
#  - (similarity: 0.59) [unknown_chara_602628616]: （虽然抵达了阿拜多斯自治区……）
#
#  - (similarity: 0.59) 头盔团A: 呜啊啊啊！！难，难道是阿拜多斯那伙人吗！？<br/>竟敢对我们……
#
#  - (similarity: 0.59) [unknown_chara_602628616]: （与日步美和大家一起回到阿拜多斯，所有人一起确认了文档）
#
#  - (similarity: 0.59) 无月: ……我还以为是谁，这不是阿拜多斯的眼镜妹吗～？
#
#  - (similarity: 0.59) 柴大将: 你们是阿拜多斯他们的朋友吧。<br/>要加面的话再跟我说。
#
#  - (similarity: 0.58) 佳世子: 不过阿拜多斯真的有那么危险吗？<br/>甚至不惜花光所有财产来招募佣兵？
#
#  - (similarity: 0.58) 日步美: 话说各位的债……<br/>难道阿拜多斯向凯萨信贷借了钱吗……？
#
#  - (similarity: 0.58) 野乃美: 听说是阿拜多斯最后的学生会长。<br/>好像是个非常不可靠的人，在那个人消失后就变成由星野前辈承受一切了……
#
#  - (similarity: 0.58) 亚瑠: 泳装蒙面团竟然就是阿拜多斯的人！！？？
#
#  - (similarity: 0.58) 无月: 但是阿拜多斯那些家伙比想像中还强。<br/>还有那个「夏莱」的老师在，光靠我们是行不通的。
#
#  - (similarity: 0.57) 亚瑠: 阿拜多斯，我们走着瞧。<br/>事情可不会这样就结束。
#
#  - (similarity: 0.57) 绫音: 不，那终究只是「自称」而已……<br/>我想他们现在应该已经在我们阿拜多斯的校区内才对。早上也见到面了……
#
#  - (similarity: 0.57) 白子: 运钞车的款项纪录上写着「在阿拜多斯收取788万元」。<br/>是来过我们学校的那台车没错。
#
#  - (similarity: 0.57) 彩奈: 嗯……阿拜多斯高中吗……
#
#  - (similarity: 0.57) 星野: 唔嘿～因为咱们之前一直都待在阿拜多斯境内呀～<br/>学校外面可是有很多奇怪的地方唷～
#
#  - (similarity: 0.57) 绫音: 我来向您说明。<br/>对策委员会……是有志之士为了让阿拜多斯复苏而成立的社团。
#
#  - (similarity: 0.56) 亚瑠: ……没，没错！！这下理解了吧，阿拜多斯！我究竟有多么恶劣！
#
#  - (similarity: 0.56) 日步美: 还有阿拜多斯各位的状况也是……
